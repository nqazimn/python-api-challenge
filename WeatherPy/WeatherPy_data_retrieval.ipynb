# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from api_keys import weather_api_key
import json
import time
import datetime

# Using pycountry to obtain full names of the countries
# source: https://pypi.org/project/pycountry/
import pycountry

# Adding options to display all of the rows of DataFrame w/o truncation
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Range of latitudes and longitudes
range_of_latitude = (-90, 90)
range_of_longitude = (-180, 180)

output_path = os.path.join('..','Outputs')

# %%
# List for holding cities
cities = []
countries = []

# Create a set of random lat and lng combinations
random_latitudes = np.random.uniform(low = -90, high = 90, size=1500)
random_longitudes = np.random.uniform(low = -180, high = 180, size=1500)
random_geographic_locations = zip(random_latitudes, random_longitudes)

for a_location in random_geographic_locations:
    city = citipy.nearest_city(a_location[0], a_location[1]).city_name
    country = citipy.nearest_city(a_location[0], a_location[1]).country_code
    
    # If city is unique, then append it to city list along with full country name
    if city not in cities:
        cities.append(city)
        try:
            countries.append(pycountry.countries.get(alpha_2 = country.upper()).name)
        except:
            countries.append('N/A')

cities_and_countries = zip(cities,countries)

print(len(cities))
print(len(countries))
# Out:
# 634
# 634

# %%
# base_url = "http://api.openweathermap.org/data/2.5/weather?"
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial"

requests_per_minute = 0
elapsed_time_in_seconds = 0
record_number = 0
request_counter = 0

start_time = time.time()
print('Session started at: ' + time.ctime() + '\n')

# setup weather_df to append data
weather_df = pd.DataFrame({'City':[],\
                           'Country':[],\
                           'Country Code':[],\
                           'Date':[],\
                           'Latitude':[],\
                           'Longitude':[],\
                           'Max Temp':[],\
                           'Humidity':[],\
                           'Cloudiness':[],\
                           'Wind Speed':[]})

for _ in cities_and_countries:       
    a_city = _[0]
    a_country = _[1]       
    
    current_time = time.time()
    elapsed_time_in_seconds = round(current_time - start_time, 2)
    
    # Query OpenWeatherMap API and update counters
    query_url = base_url + '&APPID=' + weather_api_key + '&q=' + a_city
    response = requests.get(query_url)
    weather_response = response.json()
    
    request_counter = request_counter + 1
    
    record_number = record_number + 1
    if response:
        print(f'Record# {record_number}/{len(cities)} : {a_city.title()}, {a_country} : PROCESSED')
        
        try:
            response_items_df = pd.DataFrame([[a_city.title(),\
                                a_country,\
                                weather_response['sys']['country'],\
                                str(weather_response['dt']),\
                                weather_response['coord']['lat'],\
                                weather_response['coord']['lon'],\
                                weather_response['main']['temp_max'],\
                                weather_response['main']['humidity'],\
                                weather_response['clouds']['all'],\
                                weather_response['wind']['speed']]], columns=list(weather_df.columns))
                        
            weather_df = weather_df.append(response_items_df)
        except:
            pass
    else:
        print(f'Record# {record_number}/{len(cities)} : {a_city.title()}, {a_country} : NOT FOUND')
    
    if (elapsed_time_in_seconds <= 59.0 and request_counter >= 59):
        print('\nSession ended at: ' + time.ctime())
        print(f'{request_counter} requests made in {elapsed_time_in_seconds} secs')        
        print(f'\nWaiting for next minute to begin...')
        time.sleep(60.0 - elapsed_time_in_seconds)
        
        # Reset start_time and request_counter
        start_time = time.time()
        request_counter = 0
        print('\nSession continued at: ' + time.ctime())
        
#     if (request_counter == 20):
#         break
# Out:
# Session started at: Sat Feb  1 17:49:11 2020
#
# Record# 1/634 : Vaini, Tonga : PROCESSED
# Record# 2/634 : Grindavik, Iceland : PROCESSED
# Record# 3/634 : Bermejo, Bolivia, Plurinational State of : PROCESSED
# Record# 4/634 : Tocopilla, Chile : PROCESSED
# Record# 5/634 : Arraial Do Cabo, Brazil : PROCESSED
# Record# 6/634 : Odienne, Côte d'Ivoire : PROCESSED
# Record# 7/634 : Iqaluit, Canada : PROCESSED
# Record# 8/634 : Sawakin, Sudan : PROCESSED
# Record# 9/634 : Nikolskoye, Russian Federation : PROCESSED
# Record# 10/634 : Qaanaaq, Greenland : PROCESSED
# Record# 11/634 : Pak Phanang, Thailand : PROCESSED
# Record# 12/634 : Punta Arenas, Chile : PROCESSED
# Record# 13/634 : Altay, China : PROCESSED
# Record# 14/634 : Wilmington, United States : PROCESSED
# Record# 15/634 : Barrow, United States : PROCESSED
# Record# 16/634 : Shu, Kazakhstan : PROCESSED
# Record# 17/634 : Hilo, United States : PROCESSED
# Record# 18/634 : Ribeira Grande, Portugal : PROCESSED
# Record# 19/634 : Puerto Ayora, Ecuador : PROCESSED
# Record# 20/634 : Upernavik, Greenland : PROCESSED
# Record# 21/634 : Jamestown, Saint Helena, Ascension and Tristan da Cunha : PROCESSED
# Record# 22/634 : Plettenberg Bay, South Africa : PROCESSED
# Record# 23/634 : Coari, Brazil : PROCESSED
# Record# 24/634 : Butaritari, Kiribati : PROCESSED
# Record# 25/634 : Gorkovskoye, Russian Federation : NOT FOUND
# Record# 26/634 : Khatanga, Russian Federation : PROCESSED
# Record# 27/634 : Albany, Australia : PROCESSED
# Record# 28/634 : Lebu, Chile : PROCESSED
# Record# 29/634 : Luderitz, Namibia : PROCESSED
# Record# 30/634 : Dromolaxia, Cyprus : PROCESSED
# Record# 31/634 : Agadir, Morocco : PROCESSED
# Record# 32/634 : Atuona, French Polynesia : PROCESSED
# Record# 33/634 : Northam, Australia : PROCESSED
# Record# 34/634 : Chaah, Malaysia : PROCESSED
# Record# 35/634 : Ushuaia, Argentina : PROCESSED
# Record# 36/634 : Plouzane, France : PROCESSED
# Record# 37/634 : Mataura, French Polynesia : PROCESSED
# Record# 38/634 : Shaowu, China : PROCESSED
# Record# 39/634 : Hermanus, South Africa : PROCESSED
# Record# 40/634 : Talcahuano, Chile : PROCESSED
# Record# 41/634 : Torbay, Canada : PROCESSED
# Record# 42/634 : Machilipatnam, India : PROCESSED
# Record# 43/634 : Mosquera, Colombia : PROCESSED
# Record# 44/634 : Saleaula, Samoa : NOT FOUND
# Record# 45/634 : Bethel, United States : PROCESSED
# Record# 46/634 : Natagaima, Colombia : PROCESSED
# Record# 47/634 : Cherskiy, Russian Federation : PROCESSED
# Record# 48/634 : Hobart, Australia : PROCESSED
# Record# 49/634 : Airai, Palau : PROCESSED
# Record# 50/634 : Inderborskiy, Kazakhstan : NOT FOUND
# Record# 51/634 : Port Blair, India : PROCESSED
# Record# 52/634 : Lata, Solomon Islands : PROCESSED
# Record# 53/634 : Tuktoyaktuk, Canada : PROCESSED
# Record# 54/634 : Aquiraz, Brazil : PROCESSED
# Record# 55/634 : Puerto Baquerizo Moreno, Ecuador : PROCESSED
# Record# 56/634 : Ligourion, Greece : PROCESSED
# Record# 57/634 : Vila Franca Do Campo, Portugal : PROCESSED
# Record# 58/634 : Illoqqortoormiut, Greenland : NOT FOUND
# Record# 59/634 : Belushya Guba, Russian Federation : NOT FOUND
#
# Session ended at: Sat Feb  1 17:49:18 2020
# 59 requests made in 7.16 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:50:11 2020
# Record# 60/634 : Isangel, Vanuatu : PROCESSED
# Record# 61/634 : Los Llanos De Aridane, Spain : PROCESSED
# Record# 62/634 : Lompoc, United States : PROCESSED
# Record# 63/634 : Dikson, Russian Federation : PROCESSED
# Record# 64/634 : Port Alfred, South Africa : PROCESSED
# Record# 65/634 : Bluff, New Zealand : PROCESSED
# Record# 66/634 : Acuna, Mexico : NOT FOUND
# Record# 67/634 : Pevek, Russian Federation : PROCESSED
# Record# 68/634 : Biak, Indonesia : PROCESSED
# Record# 69/634 : Georgetown, Saint Helena, Ascension and Tristan da Cunha : PROCESSED
# Record# 70/634 : Busselton, Australia : PROCESSED
# Record# 71/634 : Rikitea, French Polynesia : PROCESSED
# Record# 72/634 : Ngukurr, Australia : NOT FOUND
# Record# 73/634 : Keetmanshoop, Namibia : PROCESSED
# Record# 74/634 : Tasiilaq, Greenland : PROCESSED
# Record# 75/634 : Alotau, Papua New Guinea : NOT FOUND
# Record# 76/634 : Princeton, Canada : PROCESSED
# Record# 77/634 : Acapulco, Mexico : PROCESSED
# Record# 78/634 : Lujan, Argentina : PROCESSED
# Record# 79/634 : Thompson, Canada : PROCESSED
# Record# 80/634 : Tuatapere, New Zealand : PROCESSED
# Record# 81/634 : Cidreira, Brazil : PROCESSED
# Record# 82/634 : Wanxian, China : PROCESSED
# Record# 83/634 : Kargopol, Russian Federation : PROCESSED
# Record# 84/634 : Lamar, United States : PROCESSED
# Record# 85/634 : Narsaq, Greenland : PROCESSED
# Record# 86/634 : Vidim, Russian Federation : PROCESSED
# Record# 87/634 : Miri, Malaysia : PROCESSED
# Record# 88/634 : Kolyshley, Russian Federation : PROCESSED
# Record# 89/634 : Sept-Iles, Canada : PROCESSED
# Record# 90/634 : Palabuhanratu, Indonesia : NOT FOUND
# Record# 91/634 : Ranong, Thailand : PROCESSED
# Record# 92/634 : Estelle, United States : PROCESSED
# Record# 93/634 : Port Elizabeth, South Africa : PROCESSED
# Record# 94/634 : Taolanaro, Madagascar : NOT FOUND
# Record# 95/634 : Mys Shmidta, Russian Federation : NOT FOUND
# Record# 96/634 : Kemijarvi, Finland : NOT FOUND
# Record# 97/634 : Bredasdorp, South Africa : PROCESSED
# Record# 98/634 : Mbala, Zambia : PROCESSED
# Record# 99/634 : Mersing, Malaysia : PROCESSED
# Record# 100/634 : Cape Town, South Africa : PROCESSED
# Record# 101/634 : Pemangkat, Indonesia : PROCESSED
# Record# 102/634 : Walvis Bay, Namibia : PROCESSED
# Record# 103/634 : Barentsburg, Svalbard and Jan Mayen : NOT FOUND
# Record# 104/634 : Panalingaan, Philippines : PROCESSED
# Record# 105/634 : Gatesville, United States : PROCESSED
# Record# 106/634 : Chenzhou, China : PROCESSED
# Record# 107/634 : Attawapiskat, Canada : NOT FOUND
# Record# 108/634 : Lolua, Tuvalu : NOT FOUND
# Record# 109/634 : Mudyuga, Russian Federation : NOT FOUND
# Record# 110/634 : La Ronge, Canada : PROCESSED
# Record# 111/634 : Port Hardy, Canada : PROCESSED
# Record# 112/634 : Kapaa, United States : PROCESSED
# Record# 113/634 : Salinopolis, Brazil : PROCESSED
# Record# 114/634 : Basco, Philippines : PROCESSED
# Record# 115/634 : Broome, Australia : PROCESSED
# Record# 116/634 : Carnarvon, Australia : PROCESSED
# Record# 117/634 : Boende, Congo, The Democratic Republic of the : PROCESSED
# Record# 118/634 : Mount Gambier, Australia : PROCESSED
#
# Session ended at: Sat Feb  1 17:50:18 2020
# 59 requests made in 7.04 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:51:11 2020
# Record# 119/634 : Nizhnevartovsk, Russian Federation : PROCESSED
# Record# 120/634 : Zeya, Russian Federation : PROCESSED
# Record# 121/634 : Sentyabrskiy, Russian Federation : NOT FOUND
# Record# 122/634 : Sibolga, Indonesia : PROCESSED
# Record# 123/634 : Hami, China : PROCESSED
# Record# 124/634 : Finnsnes, Norway : PROCESSED
# Record# 125/634 : Kandrian, Papua New Guinea : PROCESSED
# Record# 126/634 : Kodiak, United States : PROCESSED
# Record# 127/634 : Yellowknife, Canada : PROCESSED
# Record# 128/634 : Bengkulu, Indonesia : PROCESSED
# Record# 129/634 : Laguna, Brazil : PROCESSED
# Record# 130/634 : Guaraniacu, Brazil : PROCESSED
# Record# 131/634 : Hasaki, Japan : PROCESSED
# Record# 132/634 : Lorengau, Papua New Guinea : PROCESSED
# Record# 133/634 : Lavrentiya, Russian Federation : PROCESSED
# Record# 134/634 : Eunice, United States : PROCESSED
# Record# 135/634 : Maldonado, Uruguay : PROCESSED
# Record# 136/634 : Goderich, Sierra Leone : PROCESSED
# Record# 137/634 : Zhezkazgan, Kazakhstan : PROCESSED
# Record# 138/634 : Talnakh, Russian Federation : PROCESSED
# Record# 139/634 : Jinka, Ethiopia : PROCESSED
# Record# 140/634 : Killarney, Canada : PROCESSED
# Record# 141/634 : Kaitangata, New Zealand : PROCESSED
# Record# 142/634 : Miguel Calmon, Brazil : PROCESSED
# Record# 143/634 : Kabompo, Zambia : PROCESSED
# Record# 144/634 : Vaitupu, Wallis and Futuna : NOT FOUND
# Record# 145/634 : Nouakchott, Mauritania : PROCESSED
# Record# 146/634 : Kaa-Khem, Russian Federation : PROCESSED
# Record# 147/634 : Faanui, French Polynesia : PROCESSED
# Record# 148/634 : Mbandaka, Congo, The Democratic Republic of the : PROCESSED
# Record# 149/634 : Cabo San Lucas, Mexico : PROCESSED
# Record# 150/634 : Waitara, New Zealand : PROCESSED
# Record# 151/634 : Dzhusaly, Kazakhstan : NOT FOUND
# Record# 152/634 : Gamba, Gabon : PROCESSED
# Record# 153/634 : Marawi, Sudan : PROCESSED
# Record# 154/634 : Dingle, Ireland : PROCESSED
# Record# 155/634 : Saint George, Bermuda : PROCESSED
# Record# 156/634 : Tiksi, Russian Federation : PROCESSED
# Record# 157/634 : Rameshki, Russian Federation : PROCESSED
# Record# 158/634 : Baruun-Urt, Mongolia : PROCESSED
# Record# 159/634 : Fortuna, United States : PROCESSED
# Record# 160/634 : Marcona, Peru : NOT FOUND
# Record# 161/634 : Clyde River, Canada : PROCESSED
# Record# 162/634 : Hirara, Japan : PROCESSED
# Record# 163/634 : Castro, Chile : PROCESSED
# Record# 164/634 : Salalah, Oman : PROCESSED
# Record# 165/634 : Rio Gallegos, Argentina : PROCESSED
# Record# 166/634 : Dordrecht, South Africa : PROCESSED
# Record# 167/634 : Wanning, China : PROCESSED
# Record# 168/634 : Husavik, Iceland : PROCESSED
# Record# 169/634 : Victor Harbor, Australia : PROCESSED
# Record# 170/634 : Kavieng, Papua New Guinea : PROCESSED
# Record# 171/634 : Abu Samrah, Qatar : PROCESSED
# Record# 172/634 : Amazar, Russian Federation : PROCESSED
# Record# 173/634 : Colquechaca, Bolivia, Plurinational State of : PROCESSED
# Record# 174/634 : Touros, Brazil : PROCESSED
# Record# 175/634 : Natal, Brazil : PROCESSED
# Record# 176/634 : Spilimbergo, Italy : PROCESSED
# Record# 177/634 : Malakal, Sudan : PROCESSED
#
# Session ended at: Sat Feb  1 17:51:19 2020
# 59 requests made in 7.22 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:52:11 2020
# Record# 178/634 : Geraldton, Australia : PROCESSED
# Record# 179/634 : Chara, Russian Federation : PROCESSED
# Record# 180/634 : Cornelius, United States : PROCESSED
# Record# 181/634 : Develi, Turkey : PROCESSED
# Record# 182/634 : Camargo, Mexico : PROCESSED
# Record# 183/634 : Nome, United States : PROCESSED
# Record# 184/634 : New Norfolk, Australia : PROCESSED
# Record# 185/634 : Arman, Russian Federation : PROCESSED
# Record# 186/634 : Mokshan, Russian Federation : PROCESSED
# Record# 187/634 : Madrid, Mexico : PROCESSED
# Record# 188/634 : Kavaratti, India : PROCESSED
# Record# 189/634 : Uruzgan, Afghanistan : PROCESSED
# Record# 190/634 : Birjand, Iran, Islamic Republic of : PROCESSED
# Record# 191/634 : Port Hedland, Australia : PROCESSED
# Record# 192/634 : Alice Springs, Australia : PROCESSED
# Record# 193/634 : Batagay-Alyta, Russian Federation : PROCESSED
# Record# 194/634 : Barcelos, Brazil : PROCESSED
# Record# 195/634 : Mount Isa, Australia : PROCESSED
# Record# 196/634 : Novobureyskiy, Russian Federation : PROCESSED
# Record# 197/634 : Ayame, Côte d'Ivoire : PROCESSED
# Record# 198/634 : Bathsheba, Barbados : PROCESSED
# Record# 199/634 : Ostrovnoy, Russian Federation : PROCESSED
# Record# 200/634 : Avarua, Cook Islands : PROCESSED
# Record# 201/634 : Pacific Grove, United States : PROCESSED
# Record# 202/634 : Trairi, Brazil : PROCESSED
# Record# 203/634 : Consett, United Kingdom : PROCESSED
# Record# 204/634 : Kahului, United States : PROCESSED
# Record# 205/634 : Vrangel, Russian Federation : PROCESSED
# Record# 206/634 : Kandi, Benin : PROCESSED
# Record# 207/634 : Saskylakh, Russian Federation : PROCESSED
# Record# 208/634 : Moron, Mongolia : PROCESSED
# Record# 209/634 : Warqla, Algeria : NOT FOUND
# Record# 210/634 : Ponta Do Sol, Cabo Verde : PROCESSED
# Record# 211/634 : Marau, Brazil : PROCESSED
# Record# 212/634 : Labutta, Myanmar : NOT FOUND
# Record# 213/634 : Huajuapan, Mexico : NOT FOUND
# Record# 214/634 : Verkhoyansk, Russian Federation : PROCESSED
# Record# 215/634 : Miles City, United States : PROCESSED
# Record# 216/634 : Peniche, Portugal : PROCESSED
# Record# 217/634 : Bambous Virieux, Mauritius : PROCESSED
# Record# 218/634 : Agva, Turkey : NOT FOUND
# Record# 219/634 : Abu Zabad, Sudan : PROCESSED
# Record# 220/634 : Pueblo Rico, Colombia : PROCESSED
# Record# 221/634 : Kishtwar, India : PROCESSED
# Record# 222/634 : Beringovskiy, Russian Federation : PROCESSED
# Record# 223/634 : Savonlinna, Finland : PROCESSED
# Record# 224/634 : Gushikawa, Japan : PROCESSED
# Record# 225/634 : Kathmandu, Nepal : PROCESSED
# Record# 226/634 : Murgab, Turkmenistan : PROCESSED
# Record# 227/634 : Klaksvik, Faroe Islands : PROCESSED
# Record# 228/634 : Soyo, Angola : PROCESSED
# Record# 229/634 : Lao Cai, Viet Nam : PROCESSED
# Record# 230/634 : Chokurdakh, Russian Federation : PROCESSED
# Record# 231/634 : Srednekolymsk, Russian Federation : PROCESSED
# Record# 232/634 : Vestmanna, Faroe Islands : PROCESSED
# Record# 233/634 : Tumaco, Colombia : PROCESSED
# Record# 234/634 : Hamilton, Bermuda : PROCESSED
# Record# 235/634 : Severo-Kurilsk, Russian Federation : PROCESSED
# Record# 236/634 : Paamiut, Greenland : PROCESSED
#
# Session ended at: Sat Feb  1 17:52:19 2020
# 59 requests made in 7.3 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:53:11 2020
# Record# 237/634 : Yumen, China : PROCESSED
# Record# 238/634 : Solovetskiy, Russian Federation : NOT FOUND
# Record# 239/634 : Muravlenko, Russian Federation : PROCESSED
# Record# 240/634 : Hohhot, China : PROCESSED
# Record# 241/634 : Bukachacha, Russian Federation : PROCESSED
# Record# 242/634 : Isla Mujeres, Mexico : PROCESSED
# Record# 243/634 : Esperance, Australia : PROCESSED
# Record# 244/634 : Alofi, Niue : PROCESSED
# Record# 245/634 : Ayan, Russian Federation : PROCESSED
# Record# 246/634 : Qasigiannguit, Greenland : PROCESSED
# Record# 247/634 : Flinders, Australia : PROCESSED
# Record# 248/634 : Lucea, Jamaica : PROCESSED
# Record# 249/634 : Barabai, Indonesia : PROCESSED
# Record# 250/634 : Lumphat, Cambodia : PROCESSED
# Record# 251/634 : Olafsvik, Iceland : PROCESSED
# Record# 252/634 : Amderma, Russian Federation : NOT FOUND
# Record# 253/634 : Chihuahua, Mexico : PROCESSED
# Record# 254/634 : Yerbogachen, Russian Federation : PROCESSED
# Record# 255/634 : Haines Junction, Canada : PROCESSED
# Record# 256/634 : Half Moon Bay, United States : PROCESSED
# Record# 257/634 : Cayenne, French Guiana : PROCESSED
# Record# 258/634 : Dudinka, Russian Federation : PROCESSED
# Record# 259/634 : Constitucion, Mexico : PROCESSED
# Record# 260/634 : Porgera, Papua New Guinea : PROCESSED
# Record# 261/634 : Cap-Aux-Meules, Canada : PROCESSED
# Record# 262/634 : Namtsy, Russian Federation : PROCESSED
# Record# 263/634 : Aklavik, Canada : PROCESSED
# Record# 264/634 : Rio Grande, Brazil : PROCESSED
# Record# 265/634 : Tura, Russian Federation : PROCESSED
# Record# 266/634 : Tsihombe, Madagascar : NOT FOUND
# Record# 267/634 : Havre-Saint-Pierre, Canada : PROCESSED
# Record# 268/634 : Ballina, Australia : PROCESSED
# Record# 269/634 : Consuegra, Spain : PROCESSED
# Record# 270/634 : Victoria, Seychelles : PROCESSED
# Record# 271/634 : Brownwood, United States : PROCESSED
# Record# 272/634 : Kalat, Pakistan : PROCESSED
# Record# 273/634 : Talah, Tunisia : NOT FOUND
# Record# 274/634 : Burica, Panama : NOT FOUND
# Record# 275/634 : Nouadhibou, Mauritania : PROCESSED
# Record# 276/634 : Hithadhoo, Maldives : PROCESSED
# Record# 277/634 : Portland, Australia : PROCESSED
# Record# 278/634 : Kruisfontein, South Africa : PROCESSED
# Record# 279/634 : Kondinskoye, Russian Federation : PROCESSED
# Record# 280/634 : Iskilip, Turkey : PROCESSED
# Record# 281/634 : Kaeo, New Zealand : PROCESSED
# Record# 282/634 : Popondetta, Papua New Guinea : PROCESSED
# Record# 283/634 : Quthing, Lesotho : PROCESSED
# Record# 284/634 : Mar Del Plata, Argentina : PROCESSED
# Record# 285/634 : Praxedis Guerrero, Mexico : PROCESSED
# Record# 286/634 : Karratha, Australia : PROCESSED
# Record# 287/634 : Opobo, Nigeria : NOT FOUND
# Record# 288/634 : Thunder Bay, Canada : PROCESSED
# Record# 289/634 : Inhambane, Mozambique : PROCESSED
# Record# 290/634 : Motzorongo, Mexico : PROCESSED
# Record# 291/634 : Douentza, Mali : PROCESSED
# Record# 292/634 : Mayor Pablo Lagerenza, Paraguay : PROCESSED
# Record# 293/634 : Necochea, Argentina : PROCESSED
# Record# 294/634 : Nanortalik, Greenland : PROCESSED
# Record# 295/634 : La Uribe, Colombia : NOT FOUND
#
# Session ended at: Sat Feb  1 17:53:19 2020
# 59 requests made in 7.3 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:54:12 2020
# Record# 296/634 : Krasnovishersk, Russian Federation : PROCESSED
# Record# 297/634 : Kajaani, Finland : PROCESSED
# Record# 298/634 : Yanam, India : PROCESSED
# Record# 299/634 : Umm Kaddadah, Sudan : PROCESSED
# Record# 300/634 : Kopeysk, Russian Federation : PROCESSED
# Record# 301/634 : Westport, Ireland : PROCESSED
# Record# 302/634 : Baker City, United States : PROCESSED
# Record# 303/634 : Andalan, Philippines : PROCESSED
# Record# 304/634 : Sao Paulo De Olivenca, Brazil : PROCESSED
# Record# 305/634 : Abyek, Iran, Islamic Republic of : PROCESSED
# Record# 306/634 : Saint-Pierre, Réunion : PROCESSED
# Record# 307/634 : Port Lincoln, Australia : PROCESSED
# Record# 308/634 : Pathein, Myanmar : PROCESSED
# Record# 309/634 : Teya, Russian Federation : PROCESSED
# Record# 310/634 : Kribi, Cameroon : PROCESSED
# Record# 311/634 : Provideniya, Russian Federation : PROCESSED
# Record# 312/634 : Katsuura, Japan : PROCESSED
# Record# 313/634 : Bridlington, United Kingdom : PROCESSED
# Record# 314/634 : Marsh Harbour, Bahamas : PROCESSED
# Record# 315/634 : Kurmanayevka, Russian Federation : PROCESSED
# Record# 316/634 : Waddan, Libya : PROCESSED
# Record# 317/634 : Tongchuan, China : PROCESSED
# Record# 318/634 : Ilulissat, Greenland : PROCESSED
# Record# 319/634 : Sao Joao Da Barra, Brazil : PROCESSED
# Record# 320/634 : Praia Da Vitoria, Portugal : PROCESSED
# Record# 321/634 : Fagersta, Sweden : PROCESSED
# Record# 322/634 : Berbera, Somalia : PROCESSED
# Record# 323/634 : Louisbourg, Canada : NOT FOUND
# Record# 324/634 : Ouallam, Niger : PROCESSED
# Record# 325/634 : San Quintin, Mexico : PROCESSED
# Record# 326/634 : Kenai, United States : PROCESSED
# Record# 327/634 : Jumilla, Spain : PROCESSED
# Record# 328/634 : Umea, Sweden : PROCESSED
# Record# 329/634 : Green River, United States : PROCESSED
# Record# 330/634 : Okhotsk, Russian Federation : PROCESSED
# Record# 331/634 : Pimentel, Peru : PROCESSED
# Record# 332/634 : Nuuk, Greenland : PROCESSED
# Record# 333/634 : Korem, Ethiopia : PROCESSED
# Record# 334/634 : Sao Felix Do Xingu, Brazil : PROCESSED
# Record# 335/634 : Yulara, Australia : PROCESSED
# Record# 336/634 : Nizwa, Oman : PROCESSED
# Record# 337/634 : Nizhneyansk, Russian Federation : NOT FOUND
# Record# 338/634 : Shelburne, Canada : PROCESSED
# Record# 339/634 : Luganville, Vanuatu : PROCESSED
# Record# 340/634 : Cervo, Spain : PROCESSED
# Record# 341/634 : Cortez, United States : PROCESSED
# Record# 342/634 : Opotiki, New Zealand : PROCESSED
# Record# 343/634 : Pontalina, Brazil : PROCESSED
# Record# 344/634 : Coahuayana, Mexico : PROCESSED
# Record# 345/634 : Carutapera, Brazil : PROCESSED
# Record# 346/634 : Cuamba, Mozambique : PROCESSED
# Record# 347/634 : Umzimvubu, South Africa : NOT FOUND
# Record# 348/634 : Linjiang, China : PROCESSED
# Record# 349/634 : Te Anau, New Zealand : PROCESSED
# Record# 350/634 : Burns Lake, Canada : PROCESSED
# Record# 351/634 : Wulanhaote, China : NOT FOUND
# Record# 352/634 : Niquelandia, Brazil : PROCESSED
# Record# 353/634 : Avanigadda, India : PROCESSED
# Record# 354/634 : Longyearbyen, Svalbard and Jan Mayen : PROCESSED
#
# Session ended at: Sat Feb  1 17:54:19 2020
# 59 requests made in 7.1 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:55:12 2020
# Record# 355/634 : Zhigansk, Russian Federation : PROCESSED
# Record# 356/634 : Opuwo, Namibia : PROCESSED
# Record# 357/634 : Kharabali, Russian Federation : PROCESSED
# Record# 358/634 : Bara, Sudan : PROCESSED
# Record# 359/634 : Port-Gentil, Gabon : PROCESSED
# Record# 360/634 : Malaya Purga, Russian Federation : PROCESSED
# Record# 361/634 : Norman Wells, Canada : PROCESSED
# Record# 362/634 : Jabiru, Australia : NOT FOUND
# Record# 363/634 : Nobeoka, Japan : PROCESSED
# Record# 364/634 : Pangnirtung, Canada : PROCESSED
# Record# 365/634 : Ixtapa, Mexico : PROCESSED
# Record# 366/634 : Namibe, Angola : PROCESSED
# Record# 367/634 : Marathon, United States : PROCESSED
# Record# 368/634 : Phan Rang, Viet Nam : NOT FOUND
# Record# 369/634 : Balikpapan, Indonesia : PROCESSED
# Record# 370/634 : Marzuq, Libya : PROCESSED
# Record# 371/634 : Shenjiamen, China : PROCESSED
# Record# 372/634 : Alihe, China : PROCESSED
# Record# 373/634 : Novaya Igirma, Russian Federation : PROCESSED
# Record# 374/634 : Lagoa, Portugal : PROCESSED
# Record# 375/634 : Nhulunbuy, Australia : PROCESSED
# Record# 376/634 : Baghdad, Iraq : PROCESSED
# Record# 377/634 : Rungata, Kiribati : NOT FOUND
# Record# 378/634 : Palkaka, Honduras : NOT FOUND
# Record# 379/634 : Vardo, Norway : PROCESSED
# Record# 380/634 : Porto Torres, Italy : PROCESSED
# Record# 381/634 : Kysyl-Syr, Russian Federation : PROCESSED
# Record# 382/634 : Lubumbashi, Congo, The Democratic Republic of the : PROCESSED
# Record# 383/634 : Bushehr, Iran, Islamic Republic of : PROCESSED
# Record# 384/634 : Ruwi, Oman : PROCESSED
# Record# 385/634 : Paris, United States : PROCESSED
# Record# 386/634 : Muros, Spain : PROCESSED
# Record# 387/634 : Barreirinhas, Brazil : PROCESSED
# Record# 388/634 : Sompeta, India : PROCESSED
# Record# 389/634 : Galveston, United States : PROCESSED
# Record# 390/634 : Khed, India : PROCESSED
# Record# 391/634 : Yenagoa, Nigeria : PROCESSED
# Record# 392/634 : Tarko-Sale, Russian Federation : PROCESSED
# Record# 393/634 : Izhma, Russian Federation : PROCESSED
# Record# 394/634 : Ulagan, Russian Federation : PROCESSED
# Record# 395/634 : Nara, Mali : PROCESSED
# Record# 396/634 : Codrington, Antigua and Barbuda : PROCESSED
# Record# 397/634 : Russell, New Zealand : PROCESSED
# Record# 398/634 : Kirovsk, Russian Federation : PROCESSED
# Record# 399/634 : Mumford, Ghana : PROCESSED
# Record# 400/634 : Caravelas, Brazil : PROCESSED
# Record# 401/634 : Belen, Nicaragua : PROCESSED
# Record# 402/634 : Ambilobe, Madagascar : PROCESSED
# Record# 403/634 : Pafos, Cyprus : PROCESSED
# Record# 404/634 : Mlonggo, Indonesia : PROCESSED
# Record# 405/634 : Ilhabela, Brazil : PROCESSED
# Record# 406/634 : Halalo, Wallis and Futuna : NOT FOUND
# Record# 407/634 : Yinchuan, China : PROCESSED
# Record# 408/634 : Moulmeingyun, Myanmar : NOT FOUND
# Record# 409/634 : Dubai, United Arab Emirates : PROCESSED
# Record# 410/634 : Omaruru, Namibia : PROCESSED
# Record# 411/634 : Mandurah, Australia : PROCESSED
# Record# 412/634 : Eureka, United States : PROCESSED
# Record# 413/634 : East London, South Africa : PROCESSED
#
# Session ended at: Sat Feb  1 17:55:19 2020
# 59 requests made in 7.1 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:56:12 2020
# Record# 414/634 : Saint-Joseph, Réunion : PROCESSED
# Record# 415/634 : Batemans Bay, Australia : PROCESSED
# Record# 416/634 : Ukiah, United States : PROCESSED
# Record# 417/634 : Sitka, United States : PROCESSED
# Record# 418/634 : Southbridge, New Zealand : PROCESSED
# Record# 419/634 : Kangaatsiaq, Greenland : PROCESSED
# Record# 420/634 : Avera, French Polynesia : PROCESSED
# Record# 421/634 : Macapa, Brazil : PROCESSED
# Record# 422/634 : Saldanha, South Africa : PROCESSED
# Record# 423/634 : Hay River, Canada : PROCESSED
# Record# 424/634 : Shimoda, Japan : PROCESSED
# Record# 425/634 : Teguise, Spain : PROCESSED
# Record# 426/634 : Kalmunai, Sri Lanka : PROCESSED
# Record# 427/634 : Usinsk, Russian Federation : PROCESSED
# Record# 428/634 : Bokspits, Botswana : NOT FOUND
# Record# 429/634 : Zhanaozen, Kazakhstan : PROCESSED
# Record# 430/634 : Villarrubia De Los Ojos, Spain : PROCESSED
# Record# 431/634 : Vung Tau, Viet Nam : PROCESSED
# Record# 432/634 : Bar Harbor, United States : PROCESSED
# Record# 433/634 : Chuy, Uruguay : PROCESSED
# Record# 434/634 : Karauzyak, Uzbekistan : NOT FOUND
# Record# 435/634 : Axim, Ghana : PROCESSED
# Record# 436/634 : Arklow, Ireland : PROCESSED
# Record# 437/634 : Grand River South East, Mauritius : NOT FOUND
# Record# 438/634 : Sandpoint, United States : PROCESSED
# Record# 439/634 : Coquimbo, Chile : PROCESSED
# Record# 440/634 : Burnie, Australia : PROCESSED
# Record# 441/634 : Waipawa, New Zealand : PROCESSED
# Record# 442/634 : Guerrero Negro, Mexico : PROCESSED
# Record# 443/634 : Tumpat, Malaysia : PROCESSED
# Record# 444/634 : Solnechnyy, Russian Federation : PROCESSED
# Record# 445/634 : Nishihara, Japan : PROCESSED
# Record# 446/634 : Mamallapuram, India : PROCESSED
# Record# 447/634 : Ucluelet, Canada : PROCESSED
# Record# 448/634 : Ampanihy, Madagascar : PROCESSED
# Record# 449/634 : Peleduy, Russian Federation : PROCESSED
# Record# 450/634 : Savinka, Russian Federation : PROCESSED
# Record# 451/634 : Pimenta Bueno, Brazil : PROCESSED
# Record# 452/634 : Ancud, Chile : PROCESSED
# Record# 453/634 : Rocha, Uruguay : PROCESSED
# Record# 454/634 : Rosarito, Mexico : PROCESSED
# Record# 455/634 : Cairns, Australia : PROCESSED
# Record# 456/634 : Buraydah, Saudi Arabia : PROCESSED
# Record# 457/634 : Cerro Blanco, Honduras : PROCESSED
# Record# 458/634 : Kalininsk, Russian Federation : PROCESSED
# Record# 459/634 : Sao Jose Da Coroa Grande, Brazil : PROCESSED
# Record# 460/634 : Kulhudhuffushi, Maldives : PROCESSED
# Record# 461/634 : Bonthe, Sierra Leone : PROCESSED
# Record# 462/634 : Uhingen, Germany : PROCESSED
# Record# 463/634 : Vanimo, Papua New Guinea : PROCESSED
# Record# 464/634 : Botngard, Norway : PROCESSED
# Record# 465/634 : Kangaba, Mali : PROCESSED
# Record# 466/634 : Shiyan, China : PROCESSED
# Record# 467/634 : Kudahuvadhoo, Maldives : PROCESSED
# Record# 468/634 : Huarmey, Peru : PROCESSED
# Record# 469/634 : Bontang, Indonesia : PROCESSED
# Record# 470/634 : Sao Gabriel Da Cachoeira, Brazil : PROCESSED
# Record# 471/634 : Broken Hill, Australia : PROCESSED
# Record# 472/634 : Mezen, Russian Federation : PROCESSED
#
# Session ended at: Sat Feb  1 17:56:19 2020
# 59 requests made in 7.2 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:57:12 2020
# Record# 473/634 : Vaitape, French Polynesia : PROCESSED
# Record# 474/634 : Darhan, Mongolia : PROCESSED
# Record# 475/634 : Swindon, United Kingdom : PROCESSED
# Record# 476/634 : Sikasso, Mali : PROCESSED
# Record# 477/634 : Mesyagutovo, Russian Federation : PROCESSED
# Record# 478/634 : Vagur, Faroe Islands : PROCESSED
# Record# 479/634 : Naze, Japan : PROCESSED
# Record# 480/634 : Souillac, Mauritius : PROCESSED
# Record# 481/634 : Satitoa, Samoa : NOT FOUND
# Record# 482/634 : Causapscal, Canada : PROCESSED
# Record# 483/634 : Margate, South Africa : PROCESSED
# Record# 484/634 : Himatangi, New Zealand : PROCESSED
# Record# 485/634 : Zanjan, Iran, Islamic Republic of : PROCESSED
# Record# 486/634 : Fort Nelson, Canada : PROCESSED
# Record# 487/634 : Turayf, Saudi Arabia : PROCESSED
# Record# 488/634 : Kytlym, Russian Federation : NOT FOUND
# Record# 489/634 : Mayo, Canada : PROCESSED
# Record# 490/634 : Saint-Philippe, Réunion : PROCESSED
# Record# 491/634 : Adre, Chad : PROCESSED
# Record# 492/634 : Mahebourg, Mauritius : PROCESSED
# Record# 493/634 : Constantine, Algeria : PROCESSED
# Record# 494/634 : Tecoanapa, Mexico : PROCESSED
# Record# 495/634 : Ndele, Central African Republic : PROCESSED
# Record# 496/634 : Yerofey Pavlovich, Russian Federation : PROCESSED
# Record# 497/634 : Liapades, Greece : NOT FOUND
# Record# 498/634 : Vangaindrano, Madagascar : PROCESSED
# Record# 499/634 : Baillif, Guadeloupe : PROCESSED
# Record# 500/634 : Imamoglu, Turkey : PROCESSED
# Record# 501/634 : Tawang, India : PROCESSED
# Record# 502/634 : Visby, Sweden : PROCESSED
# Record# 503/634 : San Patricio, Mexico : PROCESSED
# Record# 504/634 : Falealupo, Samoa : NOT FOUND
# Record# 505/634 : Puerto Escondido, Mexico : PROCESSED
# Record# 506/634 : Samusu, Samoa : NOT FOUND
# Record# 507/634 : Hansot, India : PROCESSED
# Record# 508/634 : Arbon, Switzerland : PROCESSED
# Record# 509/634 : Egvekinot, Russian Federation : PROCESSED
# Record# 510/634 : Kautokeino, Norway : PROCESSED
# Record# 511/634 : Yeppoon, Australia : PROCESSED
# Record# 512/634 : Mehamn, Norway : PROCESSED
# Record# 513/634 : Maple Creek, Canada : PROCESSED
# Record# 514/634 : Ulladulla, Australia : PROCESSED
# Record# 515/634 : Aksu, China : PROCESSED
# Record# 516/634 : Doctor Pedro P. Pena, Paraguay : NOT FOUND
# Record# 517/634 : Buala, Solomon Islands : PROCESSED
# Record# 518/634 : Hornepayne, Canada : PROCESSED
# Record# 519/634 : Morro Bay, United States : PROCESSED
# Record# 520/634 : Vatne, Norway : PROCESSED
# Record# 521/634 : Moville, Ireland : PROCESSED
# Record# 522/634 : Eberndorf, Austria : PROCESSED
# Record# 523/634 : Tagusao, Philippines : PROCESSED
# Record# 524/634 : Pavlodar, Kazakhstan : PROCESSED
# Record# 525/634 : Okandja, Gabon : NOT FOUND
# Record# 526/634 : Henties Bay, Namibia : PROCESSED
# Record# 527/634 : Bargal, Somalia : NOT FOUND
# Record# 528/634 : Sol-Iletsk, Russian Federation : PROCESSED
# Record# 529/634 : Hazaribag, India : PROCESSED
# Record# 530/634 : Mattoon, United States : PROCESSED
# Record# 531/634 : Fare, French Polynesia : PROCESSED
#
# Session ended at: Sat Feb  1 17:57:20 2020
# 59 requests made in 7.43 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:58:12 2020
# Record# 532/634 : Kendari, Indonesia : PROCESSED
# Record# 533/634 : Karpathos, Greece : PROCESSED
# Record# 534/634 : Coolum Beach, Australia : PROCESSED
# Record# 535/634 : Kudat, Malaysia : PROCESSED
# Record# 536/634 : Maceio, Brazil : PROCESSED
# Record# 537/634 : Baiao, Brazil : PROCESSED
# Record# 538/634 : Arawa, Papua New Guinea : PROCESSED
# Record# 539/634 : Sola, Vanuatu : PROCESSED
# Record# 540/634 : Aguimes, Spain : PROCESSED
# Record# 541/634 : Sur, Oman : PROCESSED
# Record# 542/634 : Chapais, Canada : PROCESSED
# Record# 543/634 : Jumla, Nepal : PROCESSED
# Record# 544/634 : Hambantota, Sri Lanka : PROCESSED
# Record# 545/634 : Havoysund, Norway : PROCESSED
# Record# 546/634 : Tumannyy, Russian Federation : NOT FOUND
# Record# 547/634 : Pandan, Philippines : PROCESSED
# Record# 548/634 : Kirakira, Solomon Islands : PROCESSED
# Record# 549/634 : Dandong, China : PROCESSED
# Record# 550/634 : Rovaniemi, Finland : PROCESSED
# Record# 551/634 : Rincon, N/A : PROCESSED
# Record# 552/634 : Porto Novo, Cabo Verde : PROCESSED
# Record# 553/634 : Fort Saint James, Canada : PROCESSED
# Record# 554/634 : Ormond Beach, United States : PROCESSED
# Record# 555/634 : Porto Nacional, Brazil : PROCESSED
# Record# 556/634 : Zalegoshch, Russian Federation : PROCESSED
# Record# 557/634 : Sao Filipe, Cabo Verde : PROCESSED
# Record# 558/634 : Soure, Brazil : PROCESSED
# Record# 559/634 : Manta, Ecuador : PROCESSED
# Record# 560/634 : Houma, United States : PROCESSED
# Record# 561/634 : Khudumelapye, Botswana : PROCESSED
# Record# 562/634 : San Jose, Guatemala : PROCESSED
# Record# 563/634 : Erzin, Russian Federation : PROCESSED
# Record# 564/634 : Cam Pha, Viet Nam : NOT FOUND
# Record# 565/634 : Anadyr, Russian Federation : PROCESSED
# Record# 566/634 : Blytheville, United States : PROCESSED
# Record# 567/634 : Vao, New Caledonia : PROCESSED
# Record# 568/634 : Vestmannaeyjar, Iceland : PROCESSED
# Record# 569/634 : Svetlogorsk, Russian Federation : PROCESSED
# Record# 570/634 : Barawe, Somalia : NOT FOUND
# Record# 571/634 : Frontera, Mexico : PROCESSED
# Record# 572/634 : Bubaque, Guinea-Bissau : PROCESSED
# Record# 573/634 : Kiama, Australia : PROCESSED
# Record# 574/634 : Riberalta, Bolivia, Plurinational State of : PROCESSED
# Record# 575/634 : Novopavlovsk, Russian Federation : PROCESSED
# Record# 576/634 : Foggia, Italy : PROCESSED
# Record# 577/634 : Bo Phloi, Thailand : PROCESSED
# Record# 578/634 : Tsagan Aman, Russian Federation : PROCESSED
# Record# 579/634 : Pychas, Russian Federation : PROCESSED
# Record# 580/634 : Nipawin, Canada : PROCESSED
# Record# 581/634 : Torres, Brazil : PROCESSED
# Record# 582/634 : Nisia Floresta, Brazil : PROCESSED
# Record# 583/634 : Petropavlovsk-Kamchatskiy, Russian Federation : PROCESSED
# Record# 584/634 : Antofagasta, Chile : PROCESSED
# Record# 585/634 : Seoul, Korea, Republic of : PROCESSED
# Record# 586/634 : Barra Dos Coqueiros, Brazil : PROCESSED
# Record# 587/634 : Monterey, United States : PROCESSED
# Record# 588/634 : Belmonte, Brazil : PROCESSED
# Record# 589/634 : Calvinia, South Africa : PROCESSED
# Record# 590/634 : Vila Velha, Brazil : PROCESSED
#
# Session ended at: Sat Feb  1 17:58:21 2020
# 59 requests made in 9.12 secs
#
# Waiting for next minute to begin...
#
# Session continued at: Sat Feb  1 17:59:12 2020
# Record# 591/634 : Najran, Saudi Arabia : PROCESSED
# Record# 592/634 : Salta, Argentina : PROCESSED
# Record# 593/634 : Belmira, Colombia : PROCESSED
# Record# 594/634 : Sarai Sidhu, Pakistan : PROCESSED
# Record# 595/634 : Biltine, Chad : PROCESSED
# Record# 596/634 : Nizhniy Odes, Russian Federation : PROCESSED
# Record# 597/634 : Floro, Norway : PROCESSED
# Record# 598/634 : Mindelo, Cabo Verde : PROCESSED
# Record# 599/634 : Whitehorse, Canada : PROCESSED
# Record# 600/634 : Mitsamiouli, Comoros : PROCESSED
# Record# 601/634 : Prince Rupert, Canada : PROCESSED
# Record# 602/634 : Riyadh, Saudi Arabia : PROCESSED
# Record# 603/634 : San Juan, United States : PROCESSED
# Record# 604/634 : Port Augusta, Australia : PROCESSED
# Record# 605/634 : Krasnoselkup, Russian Federation : PROCESSED
# Record# 606/634 : Cabedelo, Brazil : PROCESSED
# Record# 607/634 : Santa Maria, Cabo Verde : PROCESSED
# Record# 608/634 : Saint Anthony, Canada : PROCESSED
# Record# 609/634 : Mazatlan, Mexico : PROCESSED
# Record# 610/634 : Talakan, Russian Federation : PROCESSED
# Record# 611/634 : Bougouni, Mali : PROCESSED
# Record# 612/634 : Katobu, Indonesia : PROCESSED
# Record# 613/634 : Verkhnevilyuysk, Russian Federation : PROCESSED
# Record# 614/634 : Tahta, Egypt : PROCESSED
# Record# 615/634 : Nguiu, Australia : NOT FOUND
# Record# 616/634 : Kargasok, Russian Federation : PROCESSED
# Record# 617/634 : Korla, China : PROCESSED
# Record# 618/634 : Leningradskiy, Russian Federation : PROCESSED
# Record# 619/634 : Maloy, Norway : PROCESSED
# Record# 620/634 : Tatawin, Tunisia : PROCESSED
# Record# 621/634 : Escuinapa, Mexico : PROCESSED
# Record# 622/634 : San Cristobal, Ecuador : PROCESSED
# Record# 623/634 : Beloha, Madagascar : PROCESSED
# Record# 624/634 : Kushima, Japan : PROCESSED
# Record# 625/634 : Yakeshi, China : PROCESSED
# Record# 626/634 : Zhuhai, China : PROCESSED
# Record# 627/634 : Namatanai, Papua New Guinea : PROCESSED
# Record# 628/634 : Skjervoy, Norway : PROCESSED
# Record# 629/634 : Sosva, Russian Federation : PROCESSED
# Record# 630/634 : Asau, Tuvalu : PROCESSED
# Record# 631/634 : General Roca, Argentina : PROCESSED
# Record# 632/634 : Marienburg, Suriname : PROCESSED
# Record# 633/634 : Lagoa Da Prata, Brazil : PROCESSED
# Record# 634/634 : Merauke, Indonesia : PROCESSED

# %%
weather_df = weather_df.reset_index(drop=True)
print(weather_df.count())
weather_df.head(20)
# Out:
# City            578
# Country         578
# Country Code    578
# Date            578
# Latitude        578
# Longitude       578
# Max Temp        578
# Humidity        578
# Cloudiness      578
# Wind Speed      578
# dtype: int64
#                City                          Country Country Code        Date  \
# 0             Vaini                            Tonga           TO  1580600753
# 1         Grindavik                          Iceland           IS  1580600944
# 2           Bermejo  Bolivia, Plurinational State of           AR  1580600945
# 3         Tocopilla                            Chile           CL  1580600945
# 4   Arraial Do Cabo                           Brazil           BR  1580600865
# 5           Odienne                    Côte d'Ivoire           CI  1580600945
# 6           Iqaluit                           Canada           CA  1580600945
# 7           Sawakin                            Sudan           SD  1580600945
# 8        Nikolskoye               Russian Federation           RU  1580600945
# 9           Qaanaaq                        Greenland           GL  1580600946
# 10      Pak Phanang                         Thailand           TH  1580600946
# 11     Punta Arenas                            Chile           CL  1580600946
# 12            Altay                            China           CN  1580600649
# 13       Wilmington                    United States           US  1580600851
# 14           Barrow                    United States           US  1580600946
# 15              Shu                       Kazakhstan           KZ  1580600946
# 16             Hilo                    United States           US  1580600946
# 17   Ribeira Grande                         Portugal           PT  1580600947
# 18     Puerto Ayora                          Ecuador           EC  1580600947
# 19        Upernavik                        Greenland           GL  1580600947
#
#     Latitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed
# 0     -21.20    -175.20     84.20      70.0        40.0        8.05
# 1      63.84     -22.43     28.40      86.0        75.0       10.29
# 2     -32.88     -68.80     95.00      21.0        40.0        4.70
# 3     -22.09     -70.20     60.04      57.0         3.0        3.00
# 4     -22.97     -42.03     80.11      85.0        88.0       10.36
# 5       9.51      -7.57     71.22      16.0         9.0        1.43
# 6      63.75     -68.51     12.20      78.0        90.0        8.05
# 7      19.11      37.33     72.01      75.0        61.0       15.30
# 8      59.70      30.79     33.80      96.0        90.0       11.18
# 9      77.48     -69.36    -24.25      84.0        97.0        6.22
# 10      8.35     100.20     77.00      94.0        20.0        3.36
# 11    -53.15     -70.92     59.00      47.0        75.0       18.34
# 12     47.87      88.12      9.73      37.0        99.0        4.63
# 13     34.23     -77.94     48.20      93.0        90.0        5.82
# 14     71.29    -156.79    -29.20      95.0         1.0        9.17
# 15     43.60      73.76     28.00      84.0        93.0        1.01
# 16     19.73    -155.09     77.00      61.0        40.0       16.11
# 17     38.52     -28.70     55.72      76.0       100.0       12.50
# 18     -0.74     -90.35     84.20      66.0        20.0       16.11
# 19     72.79     -56.15    -25.44      96.0        63.0        9.53

# %%
weather_df.to_csv(output_path+'/weather_df.csv', index = False)
